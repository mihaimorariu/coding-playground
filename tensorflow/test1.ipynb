# %%
import tensorflow as tf
import numpy as np

# %%
# Model parameters
W = tf.Variable([.3], dtype=tf.float32)
b = tf.Variable([-.3], dtype=tf.float32)

# Model input and output
x = tf.placeholder(tf.float32)
linear_model = W * x + b
y = tf.placeholder(tf.float32)

# Loss
loss = tf.reduce_sum(tf.square(linear_model - y))

# Optimizer
optimizer = tf.train.GradientDescentOptimizer(0.01)
train = optimizer.minimize(loss)

# Training data
x_train = [1, 2, 3, 4]
y_train = [0, -1, -2, -3]

# Training loop
init = tf.global_variables_initializer()
sess = tf.Session()
sess.run(init)

for i in range(1000):
    sess.run(train, {x: [1, 2, 3, 4], y: [0, -1, -2, -3]})

# Evaluate training accuracy
curr_W, curr_b, curr_loss = sess.run([W, b, loss], {x: x_train, y:y_train})
print("W: %s b: %s loss: %s" % (curr_W, curr_b, curr_loss))
# Out:
# W: [-0.9999969] b: [ 0.99999082] loss: 5.69997e-11

# %%
features  = [tf.contrib.layers.real_valued_column("x", dimension=1)]
estimator = tf.contrib.learn.LinearRegressor(feature_columns=features)

x_train = np.array([1., 2., 3., 4.])
y_train = np.array([0., -1., -2., -3.])
x_eval  = np.array([2., 5., 8., 1.])
y_eval  = np.array([-1.01, -4.1, -7., 0.])

input_fn = tf.contrib.learn.io.numpy_input_fn(
    {"x": x_train}, y_train, batch_size=4, num_epochs=1000)
eval_input_fn = tf.contrib.learn.io.numpy_input_fn(
    {"x": x_eval}, y_eval, batch_size=4, num_epochs=1000)
estimator.fit(input_fn=input_fn, steps=1000)

train_loss = estimator.evaluate(input_fn=input_fn)
eval_loss  = estimator.evaluate(input_fn=eval_input_fn)

print("train loss: %r" % train_loss)
print("eval loss:  %r" % eval_loss)
# Out:
# INFO:tensorflow:Using default config.
# WARNING:tensorflow:Using temporary folder as model directory: /tmp/tmpqc36p221
# INFO:tensorflow:Using config: {'_task_type': None, '_task_id': 0, '_cluster_spec': <tensorflow.python.training.server_lib.ClusterSpec object at 0x7f045c760400>, '_master': '', '_num_ps_replicas': 0, '_num_worker_replicas': 0, '_environment': 'local', '_is_chief': True, '_evaluation_master': '', '_tf_config': gpu_options {
#   per_process_gpu_memory_fraction: 1
# }
# , '_tf_random_seed': None, '_save_summary_steps': 100, '_save_checkpoints_secs': 600, '_session_config': None, '_save_checkpoints_steps': None, '_keep_checkpoint_max': 5, '_keep_checkpoint_every_n_hours': 10000, '_model_dir': '/tmp/tmpqc36p221'}
# WARNING:tensorflow:From /usr/lib/python3.6/site-packages/tensorflow/contrib/learn/python/learn/estimators/head.py:625: scalar_summary (from tensorflow.python.ops.logging_ops) is deprecated and will be removed after 2016-11-30.
# Instructions for updating:
# Please switch to tf.summary.scalar. Note that tf.summary.scalar uses the node name instead of the tag. This means that TensorFlow will automatically de-duplicate summary names based on the scope they are created in. Also, passing a tensor or list of tags to a scalar summary op is no longer supported.
# INFO:tensorflow:Create CheckpointSaverHook.
# INFO:tensorflow:Saving checkpoints for 1 into /tmp/tmpqc36p221/model.ckpt.
# INFO:tensorflow:loss = 4.75, step = 1
# INFO:tensorflow:global_step/sec: 1576.57
# INFO:tensorflow:loss = 0.0998633, step = 101 (0.064 sec)
# INFO:tensorflow:global_step/sec: 1767.44
# INFO:tensorflow:loss = 0.00410941, step = 201 (0.057 sec)
# INFO:tensorflow:global_step/sec: 1655.51
# INFO:tensorflow:loss = 0.00465561, step = 301 (0.060 sec)
# INFO:tensorflow:global_step/sec: 1667.47
# INFO:tensorflow:loss = 0.000898293, step = 401 (0.060 sec)
# INFO:tensorflow:global_step/sec: 1743.05
# INFO:tensorflow:loss = 7.11902e-05, step = 501 (0.057 sec)
# INFO:tensorflow:global_step/sec: 1710.19
# INFO:tensorflow:loss = 3.59396e-05, step = 601 (0.059 sec)
# INFO:tensorflow:global_step/sec: 1715.34
# INFO:tensorflow:loss = 2.69815e-06, step = 701 (0.058 sec)
# INFO:tensorflow:global_step/sec: 1871.62
# INFO:tensorflow:loss = 6.77105e-07, step = 801 (0.053 sec)
# INFO:tensorflow:global_step/sec: 1811.56
# INFO:tensorflow:loss = 1.77418e-07, step = 901 (0.055 sec)
# INFO:tensorflow:Saving checkpoints for 1000 into /tmp/tmpqc36p221/model.ckpt.
# INFO:tensorflow:Loss for final step: 1.59382e-08.
# WARNING:tensorflow:From /usr/lib/python3.6/site-packages/tensorflow/contrib/learn/python/learn/estimators/head.py:625: scalar_summary (from tensorflow.python.ops.logging_ops) is deprecated and will be removed after 2016-11-30.
# Instructions for updating:
# Please switch to tf.summary.scalar. Note that tf.summary.scalar uses the node name instead of the tag. This means that TensorFlow will automatically de-duplicate summary names based on the scope they are created in. Also, passing a tensor or list of tags to a scalar summary op is no longer supported.
# INFO:tensorflow:Starting evaluation at 2017-07-14-14:44:48
# INFO:tensorflow:Restoring parameters from /tmp/tmpqc36p221/model.ckpt-1000
# INFO:tensorflow:Finished evaluation at 2017-07-14-14:44:48
# INFO:tensorflow:Saving dict for global step 1000: global_step = 1000, loss = 4.16878e-08
# WARNING:tensorflow:From /usr/lib/python3.6/site-packages/tensorflow/contrib/learn/python/learn/estimators/head.py:625: scalar_summary (from tensorflow.python.ops.logging_ops) is deprecated and will be removed after 2016-11-30.
# Instructions for updating:
# Please switch to tf.summary.scalar. Note that tf.summary.scalar uses the node name instead of the tag. This means that TensorFlow will automatically de-duplicate summary names based on the scope they are created in. Also, passing a tensor or list of tags to a scalar summary op is no longer supported.
# INFO:tensorflow:Starting evaluation at 2017-07-14-14:44:49
# INFO:tensorflow:Restoring parameters from /tmp/tmpqc36p221/model.ckpt-1000
# INFO:tensorflow:Finished evaluation at 2017-07-14-14:44:49
# INFO:tensorflow:Saving dict for global step 1000: global_step = 1000, loss = 0.00254231
# train loss: {'loss': 4.1687823e-08, 'global_step': 1000}
# eval loss:  {'loss': 0.0025423095, 'global_step': 1000}

# %%
def model(features, labels, mode):
    W = tf.get_variable("W", [1], dtype=tf.float64)
    b = tf.get_variable("b", [1], dtype=tf.float64)
    y = W * features["x"] + b
    
    loss = tf.reduce_sum(tf.square(y - labels))
    
    global_step = tf.train.get_global_step()
    optimizer   = tf.train.GradientDescentOptimizer(0.01)
    train       = tf.group(optimizer.minimize(loss),
                           tf.assign_add(global_step, 1))
    
    return tf.contrib.learn.ModelFnOps(
        mode=mode, predictions=y, loss=loss, train_op=train)

estimator = tf.contrib.learn.Estimator(model_fn=model)

x_train = np.array([1., 2., 3., 4.])
y_train = np.array([0., -1., -2., -3.])
x_eval  = np.array([2., 5., 8., .1])
y_eval  = np.array([-1.01, -4.1, -7., 0.])

input_fn = tf.contrib.learn.io.numpy_input_fn(
    {"x": x_train}, y_train, batch_size=4, num_epochs=1000)

estimator.fit(input_fn=input_fn, steps=1000)
train_loss = estimator.evaluate(input_fn=input_fn)
eval_loss  = estimator.evaluate(input_fn=eval_input_fn)

print("train loss: %r" % train_loss)
print("eval loss:  %r" % eval_loss)
# Out:
# INFO:tensorflow:Using default config.
# WARNING:tensorflow:Using temporary folder as model directory: /tmp/tmpscxke1bq
# INFO:tensorflow:Using config: {'_task_type': None, '_task_id': 0, '_cluster_spec': <tensorflow.python.training.server_lib.ClusterSpec object at 0x7f05d5e954a8>, '_master': '', '_num_ps_replicas': 0, '_num_worker_replicas': 0, '_environment': 'local', '_is_chief': True, '_evaluation_master': '', '_tf_config': gpu_options {
#   per_process_gpu_memory_fraction: 1
# }
# , '_tf_random_seed': None, '_save_summary_steps': 100, '_save_checkpoints_secs': 600, '_session_config': None, '_save_checkpoints_steps': None, '_keep_checkpoint_max': 5, '_keep_checkpoint_every_n_hours': 10000, '_model_dir': '/tmp/tmpscxke1bq'}
# INFO:tensorflow:Create CheckpointSaverHook.
# INFO:tensorflow:Saving checkpoints for 1 into /tmp/tmpscxke1bq/model.ckpt.
# INFO:tensorflow:loss = 41.2724411374, step = 1
# INFO:tensorflow:global_step/sec: 1840.24
# INFO:tensorflow:loss = 0.0204505041238, step = 101 (0.055 sec)
# INFO:tensorflow:global_step/sec: 2252.27
# INFO:tensorflow:loss = 0.000195914732231, step = 201 (0.044 sec)
# INFO:tensorflow:global_step/sec: 2405
# INFO:tensorflow:loss = 0.00138560778608, step = 301 (0.042 sec)
# INFO:tensorflow:global_step/sec: 2406.12
# INFO:tensorflow:loss = 0.000175597236016, step = 401 (0.042 sec)
# INFO:tensorflow:global_step/sec: 2377.74
# INFO:tensorflow:loss = 7.46360736622e-06, step = 501 (0.042 sec)
# INFO:tensorflow:global_step/sec: 2435.36
# INFO:tensorflow:loss = 1.85990238091e-06, step = 601 (0.041 sec)
# INFO:tensorflow:global_step/sec: 2363.76
# INFO:tensorflow:loss = 1.03683776645e-07, step = 701 (0.042 sec)
# INFO:tensorflow:global_step/sec: 2513.92
# INFO:tensorflow:loss = 1.54668161851e-09, step = 801 (0.040 sec)
# INFO:tensorflow:global_step/sec: 2695.67
# INFO:tensorflow:loss = 7.49642131435e-10, step = 901 (0.037 sec)
# INFO:tensorflow:Saving checkpoints for 1000 into /tmp/tmpscxke1bq/model.ckpt.
# INFO:tensorflow:Loss for final step: 9.33562445596e-11.
# INFO:tensorflow:Starting evaluation at 2017-07-14-14:45:16
# INFO:tensorflow:Restoring parameters from /tmp/tmpscxke1bq/model.ckpt-1000
# INFO:tensorflow:Finished evaluation at 2017-07-14-14:45:16
# INFO:tensorflow:Saving dict for global step 1000: global_step = 1000, loss = 5.93029e-11
# INFO:tensorflow:Starting evaluation at 2017-07-14-14:45:17
# INFO:tensorflow:Restoring parameters from /tmp/tmpscxke1bq/model.ckpt-1000
# INFO:tensorflow:Finished evaluation at 2017-07-14-14:45:17
# INFO:tensorflow:Saving dict for global step 1000: global_step = 1000, loss = 0.0101014
# train loss: {'loss': 5.9302861e-11, 'global_step': 1000}
# eval loss:  {'loss': 0.010101421, 'global_step': 1000}
